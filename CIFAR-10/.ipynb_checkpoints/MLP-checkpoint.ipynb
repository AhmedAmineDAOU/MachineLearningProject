# %% [markdown]
# # Multilayer perceptron on CIFAR-10

# %% [markdown]
# ## Imports

# %%
import keras
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.callbacks import ModelCheckpoint   
from sklearn.preprocessing import  MinMaxScaler
from sklearn.decomposition import PCA
from time import time as runtime
import sys
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

stdout = sys.stdout
sys.stdout = open('/dev/null', 'w')
sys.stdout = stdout

# %% [markdown]
# ## Loading Data & printing shapes

# %%
# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print("trainig data shape  : ",x_train.shape)
print("trainig labels shape: ",y_train.shape)

print("testing data shape  : ",x_test.shape)
print("testing labels shape: ",y_test.shape)


# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
ten = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# trainig data shape  :  (50000, 32, 32, 3)
# trainig labels shape:  (50000, 1)
# testing data shape  :  (10000, 32, 32, 3)
# testing labels shape:  (10000, 1)

# %% [markdown]
# ## Data exploration
# First data visualisation without any pre-processing on it.
# Printing 10 first images from the training set.

# %%
figure1 = plt.figure(figsize=(15,5))
aaa=x_test
for i in range(1,11):
    images = figure1.add_subplot(2, 5, i , xticks=[], yticks=[])
    images.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ## Data normalization

# %%
x_train = x_train.astype('float32')/255
x_test  = x_test.astype('float32')/255

# %% [markdown]
# # PCA

# %%
x_train = x_train.reshape((50000, 3072))
x_test = x_test.reshape((10000, 3072))

t = runtime()
pca = PCA(n_components=100)
pca.fit(x_train)


print("training PCA on training set takes: %.1f" % (runtime()-t))
t = runtime()
x_train = pca.transform(x_train)
x_test  = pca.transform(x_test)
print("Transforming training & testing set takes: %.1f" % (runtime()-t))


x_train = x_train.reshape((50000,10,10))
x_test = x_test.reshape((10000,10,10))
# Out:
# training PCA on training set takes: 12.6
# Transforming training & testing set takes: 1.2

# %% [markdown]
# ## Labels onehote Encoding & Spliting Testing data into training (90%) /Validation (10%)

# %%
len(ten)
# encoding labels to onehot

y_train = keras.utils.to_categorical(y_train, len(ten))
y_test  = keras.utils.to_categorical(y_test, len(ten))
print("[after onehote encoding]")
print("trainig labels shape: ",y_train.shape)
print("testing labels shape: ",y_test.shape,"\n")

# training set spliting into training (45000) and validation (5000) sets
(x_train, x_validation) = x_train[5000:], x_train[:5000]
(y_train, y_validation) = y_train[5000:], y_train[:5000]

print("[after spliting]")
print("trainig   data shape  : ",x_train.shape ,x_train.shape[0], 'examples')
print("validation data shape : ",x_validation.shape," ",x_validation.shape[0],  'examples')
print("testing   data shape  : ",x_test.shape,x_test.shape[0], 'examples')
# Out:
# [after onehote encoding]
# trainig labels shape:  (50000, 10)
# testing labels shape:  (10000, 10)
#
# [after spliting]
# trainig   data shape  :  (45000, 10, 10) 45000 examples
# validation data shape :  (5000, 10, 10)   5000 examples
# testing   data shape  :  (10000, 10, 10) 10000 examples

# %% [markdown]
# # MLP: Multilayer Perceptron Definition
# https://keras.io/getting-started/sequential-model-guide/

# %%
#creating a sequential model &passing a list of layers instances to it
from keras.utils.vis_utils import plot_model
MLP = Sequential([ Flatten(input_shape = x_train.shape[1:]),
                   Dense(1000, activation='relu'),#a fully-connected layer with 1000 hidden units
                   Dropout(0.6),                  #helps prevent overfitting.
                   Dense(512, activation='relu'), #a fully-connected layer with 512 hidden units
                   Dropout(0.6),                  #helps prevent overfitting
                   Dense(len(ten), activation='softmax')])#a fully-connected layer with 10 hidden units
MLP.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_10 (Flatten)         (None, 100)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 1000)              101000
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 1000)              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 512)               512512
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 618,642
# Trainable params: 618,642
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # MLP: Compiling the model

# %%
from keras import optimizers
sgd = optimizers.SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
MLP.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %% [markdown]
# # Training our MLP

# %%
#t=runtime()
checkpointer = ModelCheckpoint(filepath='MLP.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
History = MLP.fit(x_train, y_train, batch_size=200, epochs=300,
          validation_data=(x_validation, y_validation), callbacks=[checkpointer],verbose=2, shuffle=True)
#print("fitting the model took: %.1fs" % (runtime()-t))
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/300
#  - 7s - loss: 2.3922 - acc: 0.1690 - val_loss: 1.9763 - val_acc: 0.3142
#
# Epoch 00001: val_loss improved from inf to 1.97634, saving model to MLP.weights.best.hdf5
# Epoch 2/300
#  - 6s - loss: 2.1308 - acc: 0.2393 - val_loss: 1.8987 - val_acc: 0.3484
#
# Epoch 00002: val_loss improved from 1.97634 to 1.89865, saving model to MLP.weights.best.hdf5
# Epoch 3/300
#  - 6s - loss: 2.0318 - acc: 0.2712 - val_loss: 1.8531 - val_acc: 0.3704
#
# Epoch 00003: val_loss improved from 1.89865 to 1.85312, saving model to MLP.weights.best.hdf5
# Epoch 4/300
#  - 5s - loss: 1.9733 - acc: 0.2918 - val_loss: 1.8194 - val_acc: 0.3860
#
# Epoch 00004: val_loss improved from 1.85312 to 1.81938, saving model to MLP.weights.best.hdf5
# Epoch 5/300
#  - 6s - loss: 1.9304 - acc: 0.3081 - val_loss: 1.7922 - val_acc: 0.3938
#
# Epoch 00005: val_loss improved from 1.81938 to 1.79222, saving model to MLP.weights.best.hdf5
# Epoch 6/300
#  - 5s - loss: 1.9058 - acc: 0.3172 - val_loss: 1.7697 - val_acc: 0.3972
#
# Epoch 00006: val_loss improved from 1.79222 to 1.76967, saving model to MLP.weights.best.hdf5
# Epoch 7/300
#  - 5s - loss: 1.8765 - acc: 0.3292 - val_loss: 1.7509 - val_acc: 0.4050
#
# Epoch 00007: val_loss improved from 1.76967 to 1.75089, saving model to MLP.weights.best.hdf5
# Epoch 8/300
#  - 5s - loss: 1.8520 - acc: 0.3388 - val_loss: 1.7319 - val_acc: 0.4090
#
# Epoch 00008: val_loss improved from 1.75089 to 1.73194, saving model to MLP.weights.best.hdf5
# Epoch 9/300
#  - 5s - loss: 1.8363 - acc: 0.3434 - val_loss: 1.7174 - val_acc: 0.4118
#
# Epoch 00009: val_loss improved from 1.73194 to 1.71740, saving model to MLP.weights.best.hdf5
# Epoch 10/300
#  - 5s - loss: 1.8188 - acc: 0.3538 - val_loss: 1.7060 - val_acc: 0.4182
#
# Epoch 00010: val_loss improved from 1.71740 to 1.70604, saving model to MLP.weights.best.hdf5
# Epoch 11/300
#  - 5s - loss: 1.8080 - acc: 0.3578 - val_loss: 1.6938 - val_acc: 0.4206
#
# Epoch 00011: val_loss improved from 1.70604 to 1.69381, saving model to MLP.weights.best.hdf5
# Epoch 12/300
#  - 5s - loss: 1.7922 - acc: 0.3597 - val_loss: 1.6826 - val_acc: 0.4210
#
# Epoch 00012: val_loss improved from 1.69381 to 1.68260, saving model to MLP.weights.best.hdf5
# Epoch 13/300
#  - 5s - loss: 1.7806 - acc: 0.3656 - val_loss: 1.6723 - val_acc: 0.4244
#
# Epoch 00013: val_loss improved from 1.68260 to 1.67232, saving model to MLP.weights.best.hdf5
# Epoch 14/300
#  - 5s - loss: 1.7667 - acc: 0.3699 - val_loss: 1.6625 - val_acc: 0.4270
#
# Epoch 00014: val_loss improved from 1.67232 to 1.66248, saving model to MLP.weights.best.hdf5
# Epoch 15/300
#  - 6s - loss: 1.7609 - acc: 0.3720 - val_loss: 1.6539 - val_acc: 0.4286
#
# Epoch 00015: val_loss improved from 1.66248 to 1.65395, saving model to MLP.weights.best.hdf5
# Epoch 16/300
#  - 5s - loss: 1.7524 - acc: 0.3781 - val_loss: 1.6457 - val_acc: 0.4288
#
# Epoch 00016: val_loss improved from 1.65395 to 1.64575, saving model to MLP.weights.best.hdf5
# Epoch 17/300
#  - 5s - loss: 1.7433 - acc: 0.3792 - val_loss: 1.6387 - val_acc: 0.4328
#
# Epoch 00017: val_loss improved from 1.64575 to 1.63874, saving model to MLP.weights.best.hdf5
# Epoch 18/300
#  - 5s - loss: 1.7271 - acc: 0.3876 - val_loss: 1.6310 - val_acc: 0.4364
#
# Epoch 00018: val_loss improved from 1.63874 to 1.63101, saving model to MLP.weights.best.hdf5
# Epoch 19/300
#  - 5s - loss: 1.7239 - acc: 0.3872 - val_loss: 1.6249 - val_acc: 0.4366
#
# Epoch 00019: val_loss improved from 1.63101 to 1.62486, saving model to MLP.weights.best.hdf5
# Epoch 20/300
#  - 5s - loss: 1.7148 - acc: 0.3906 - val_loss: 1.6184 - val_acc: 0.4414
#
# Epoch 00020: val_loss improved from 1.62486 to 1.61840, saving model to MLP.weights.best.hdf5
# Epoch 21/300
#  - 5s - loss: 1.7088 - acc: 0.3943 - val_loss: 1.6124 - val_acc: 0.4432
#
# Epoch 00021: val_loss improved from 1.61840 to 1.61237, saving model to MLP.weights.best.hdf5
# Epoch 22/300
#  - 5s - loss: 1.7052 - acc: 0.3928 - val_loss: 1.6073 - val_acc: 0.4456
#
# Epoch 00022: val_loss improved from 1.61237 to 1.60729, saving model to MLP.weights.best.hdf5
# Epoch 23/300
#  - 5s - loss: 1.6934 - acc: 0.3995 - val_loss: 1.6012 - val_acc: 0.4478
#
# Epoch 00023: val_loss improved from 1.60729 to 1.60121, saving model to MLP.weights.best.hdf5
# Epoch 24/300
#  - 5s - loss: 1.6894 - acc: 0.4009 - val_loss: 1.5949 - val_acc: 0.4500
#
# Epoch 00024: val_loss improved from 1.60121 to 1.59491, saving model to MLP.weights.best.hdf5
# Epoch 25/300
#  - 5s - loss: 1.6853 - acc: 0.4036 - val_loss: 1.5910 - val_acc: 0.4520
#
# Epoch 00025: val_loss improved from 1.59491 to 1.59102, saving model to MLP.weights.best.hdf5
# Epoch 26/300
#  - 5s - loss: 1.6764 - acc: 0.4066 - val_loss: 1.5852 - val_acc: 0.4518
#
# Epoch 00026: val_loss improved from 1.59102 to 1.58518, saving model to MLP.weights.best.hdf5
# Epoch 27/300
#  - 5s - loss: 1.6726 - acc: 0.4047 - val_loss: 1.5806 - val_acc: 0.4518
#
# Epoch 00027: val_loss improved from 1.58518 to 1.58057, saving model to MLP.weights.best.hdf5
# Epoch 28/300
#  - 5s - loss: 1.6654 - acc: 0.4089 - val_loss: 1.5754 - val_acc: 0.4538
#
# Epoch 00028: val_loss improved from 1.58057 to 1.57535, saving model to MLP.weights.best.hdf5
# Epoch 29/300
#  - 5s - loss: 1.6648 - acc: 0.4096 - val_loss: 1.5720 - val_acc: 0.4538
#
# Epoch 00029: val_loss improved from 1.57535 to 1.57196, saving model to MLP.weights.best.hdf5
# Epoch 30/300
#  - 5s - loss: 1.6568 - acc: 0.4154 - val_loss: 1.5675 - val_acc: 0.4554
#
# Epoch 00030: val_loss improved from 1.57196 to 1.56747, saving model to MLP.weights.best.hdf5
# Epoch 31/300
#  - 5s - loss: 1.6500 - acc: 0.4129 - val_loss: 1.5629 - val_acc: 0.4582
#
# Epoch 00031: val_loss improved from 1.56747 to 1.56290, saving model to MLP.weights.best.hdf5
# Epoch 32/300
#  - 5s - loss: 1.6466 - acc: 0.4170 - val_loss: 1.5587 - val_acc: 0.4584
#
# Epoch 00032: val_loss improved from 1.56290 to 1.55869, saving model to MLP.weights.best.hdf5
# Epoch 33/300
#  - 5s - loss: 1.6423 - acc: 0.4172 - val_loss: 1.5556 - val_acc: 0.4592
#
# Epoch 00033: val_loss improved from 1.55869 to 1.55557, saving model to MLP.weights.best.hdf5
# Epoch 34/300
#  - 5s - loss: 1.6391 - acc: 0.4186 - val_loss: 1.5520 - val_acc: 0.4590
#
# Epoch 00034: val_loss improved from 1.55557 to 1.55199, saving model to MLP.weights.best.hdf5
# Epoch 35/300
#  - 5s - loss: 1.6304 - acc: 0.4219 - val_loss: 1.5473 - val_acc: 0.4596
#
# Epoch 00035: val_loss improved from 1.55199 to 1.54734, saving model to MLP.weights.best.hdf5
# Epoch 36/300
#  - 5s - loss: 1.6286 - acc: 0.4226 - val_loss: 1.5448 - val_acc: 0.4622
#
# Epoch 00036: val_loss improved from 1.54734 to 1.54481, saving model to MLP.weights.best.hdf5
# Epoch 37/300
#  - 5s - loss: 1.6248 - acc: 0.4277 - val_loss: 1.5403 - val_acc: 0.4610
#
# Epoch 00037: val_loss improved from 1.54481 to 1.54032, saving model to MLP.weights.best.hdf5
# Epoch 38/300
#  - 5s - loss: 1.6177 - acc: 0.4286 - val_loss: 1.5363 - val_acc: 0.4678
#
# Epoch 00038: val_loss improved from 1.54032 to 1.53629, saving model to MLP.weights.best.hdf5
# Epoch 39/300
#  - 5s - loss: 1.6193 - acc: 0.4268 - val_loss: 1.5328 - val_acc: 0.4654
#
# Epoch 00039: val_loss improved from 1.53629 to 1.53278, saving model to MLP.weights.best.hdf5
# Epoch 40/300
#  - 5s - loss: 1.6133 - acc: 0.4284 - val_loss: 1.5298 - val_acc: 0.4684
#
# Epoch 00040: val_loss improved from 1.53278 to 1.52976, saving model to MLP.weights.best.hdf5
# Epoch 41/300
#  - 5s - loss: 1.6080 - acc: 0.4303 - val_loss: 1.5282 - val_acc: 0.4694
#
# Epoch 00041: val_loss improved from 1.52976 to 1.52816, saving model to MLP.weights.best.hdf5
# Epoch 42/300
#  - 6s - loss: 1.6060 - acc: 0.4322 - val_loss: 1.5243 - val_acc: 0.4700
#
# Epoch 00042: val_loss improved from 1.52816 to 1.52434, saving model to MLP.weights.best.hdf5
# Epoch 43/300
#  - 5s - loss: 1.6031 - acc: 0.4330 - val_loss: 1.5206 - val_acc: 0.4728
#
# Epoch 00043: val_loss improved from 1.52434 to 1.52056, saving model to MLP.weights.best.hdf5
# Epoch 44/300
#  - 5s - loss: 1.5975 - acc: 0.4329 - val_loss: 1.5183 - val_acc: 0.4744
#
# Epoch 00044: val_loss improved from 1.52056 to 1.51829, saving model to MLP.weights.best.hdf5
# Epoch 45/300
#  - 5s - loss: 1.5940 - acc: 0.4365 - val_loss: 1.5136 - val_acc: 0.4760
#
# Epoch 00045: val_loss improved from 1.51829 to 1.51361, saving model to MLP.weights.best.hdf5
# Epoch 46/300
#  - 5s - loss: 1.5906 - acc: 0.4351 - val_loss: 1.5107 - val_acc: 0.4738
# Epoch 00046: val_loss improved from 1.51361 to 1.51072, saving model to MLP.weights.best.hdf5
# Epoch 47/300
#  - 5s - loss: 1.5875 - acc: 0.4376 - val_loss: 1.5095 - val_acc: 0.4768
#
# Epoch 00047: val_loss improved from 1.51072 to 1.50953, saving model to MLP.weights.best.hdf5
# Epoch 48/300
#  - 5s - loss: 1.5841 - acc: 0.4384 - val_loss: 1.5063 - val_acc: 0.4760
#
# Epoch 00048: val_loss improved from 1.50953 to 1.50628, saving model to MLP.weights.best.hdf5
# Epoch 49/300
#  - 5s - loss: 1.5826 - acc: 0.4370 - val_loss: 1.5031 - val_acc: 0.4756
#
# Epoch 00049: val_loss improved from 1.50628 to 1.50307, saving model to MLP.weights.best.hdf5
# Epoch 50/300
#  - 5s - loss: 1.5818 - acc: 0.4414 - val_loss: 1.5011 - val_acc: 0.4786
#
# Epoch 00050: val_loss improved from 1.50307 to 1.50111, saving model to MLP.weights.best.hdf5
# Epoch 51/300
#  - 5s - loss: 1.5751 - acc: 0.4406 - val_loss: 1.4981 - val_acc: 0.4788
#
# Epoch 00051: val_loss improved from 1.50111 to 1.49811, saving model to MLP.weights.best.hdf5
# Epoch 52/300
#  - 5s - loss: 1.5710 - acc: 0.4414 - val_loss: 1.4938 - val_acc: 0.4798
#
# Epoch 00052: val_loss improved from 1.49811 to 1.49375, saving model to MLP.weights.best.hdf5
# Epoch 53/300
#  - 5s - loss: 1.5680 - acc: 0.4441 - val_loss: 1.4891 - val_acc: 0.4826
#
# Epoch 00053: val_loss improved from 1.49375 to 1.48908, saving model to MLP.weights.best.hdf5
# Epoch 54/300
#  - 5s - loss: 1.5664 - acc: 0.4467 - val_loss: 1.4896 - val_acc: 0.4804
#
# Epoch 00054: val_loss did not improve from 1.48908
# Epoch 55/300
#  - 5s - loss: 1.5619 - acc: 0.4498 - val_loss: 1.4861 - val_acc: 0.4848
#
# Epoch 00055: val_loss improved from 1.48908 to 1.48614, saving model to MLP.weights.best.hdf5
# Epoch 56/300
#  - 5s - loss: 1.5572 - acc: 0.4494 - val_loss: 1.4824 - val_acc: 0.4836
#
# Epoch 00056: val_loss improved from 1.48614 to 1.48241, saving model to MLP.weights.best.hdf5
# Epoch 57/300
#  - 5s - loss: 1.5558 - acc: 0.4518 - val_loss: 1.4793 - val_acc: 0.4840
#
# Epoch 00057: val_loss improved from 1.48241 to 1.47928, saving model to MLP.weights.best.hdf5
# Epoch 58/300
#  - 5s - loss: 1.5555 - acc: 0.4495 - val_loss: 1.4776 - val_acc: 0.4848
#
# Epoch 00058: val_loss improved from 1.47928 to 1.47761, saving model to MLP.weights.best.hdf5
# Epoch 59/300
#  - 5s - loss: 1.5520 - acc: 0.4502 - val_loss: 1.4757 - val_acc: 0.4846
#
# Epoch 00059: val_loss improved from 1.47761 to 1.47567, saving model to MLP.weights.best.hdf5
# Epoch 60/300
#  - 5s - loss: 1.5512 - acc: 0.4495 - val_loss: 1.4741 - val_acc: 0.4860
#
# Epoch 00060: val_loss improved from 1.47567 to 1.47406, saving model to MLP.weights.best.hdf5
# Epoch 61/300
#  - 5s - loss: 1.5484 - acc: 0.4506 - val_loss: 1.4717 - val_acc: 0.4842
#
# Epoch 00061: val_loss improved from 1.47406 to 1.47170, saving model to MLP.weights.best.hdf5
# Epoch 62/300
#  - 5s - loss: 1.5454 - acc: 0.4509 - val_loss: 1.4694 - val_acc: 0.4870
#
# Epoch 00062: val_loss improved from 1.47170 to 1.46939, saving model to MLP.weights.best.hdf5
# Epoch 63/300
#  - 5s - loss: 1.5401 - acc: 0.4551 - val_loss: 1.4667 - val_acc: 0.4862
#
# Epoch 00063: val_loss improved from 1.46939 to 1.46666, saving model to MLP.weights.best.hdf5
# Epoch 64/300
#  - 5s - loss: 1.5426 - acc: 0.4528 - val_loss: 1.4658 - val_acc: 0.4874
#
# Epoch 00064: val_loss improved from 1.46666 to 1.46576, saving model to MLP.weights.best.hdf5
# Epoch 65/300
#  - 5s - loss: 1.5362 - acc: 0.4538 - val_loss: 1.4636 - val_acc: 0.4872
#
# Epoch 00065: val_loss improved from 1.46576 to 1.46357, saving model to MLP.weights.best.hdf5
# Epoch 66/300
#  - 5s - loss: 1.5359 - acc: 0.4583 - val_loss: 1.4601 - val_acc: 0.4870
#
# Epoch 00066: val_loss improved from 1.46357 to 1.46007, saving model to MLP.weights.best.hdf5
# Epoch 67/300
#  - 5s - loss: 1.5344 - acc: 0.4531 - val_loss: 1.4583 - val_acc: 0.4892
#
# Epoch 00067: val_loss improved from 1.46007 to 1.45834, saving model to MLP.weights.best.hdf5
# Epoch 68/300
#  - 5s - loss: 1.5297 - acc: 0.4554 - val_loss: 1.4578 - val_acc: 0.4892
#
# Epoch 00068: val_loss improved from 1.45834 to 1.45784, saving model to MLP.weights.best.hdf5
# Epoch 69/300
#  - 5s - loss: 1.5239 - acc: 0.4601 - val_loss: 1.4545 - val_acc: 0.4920
#
# Epoch 00069: val_loss improved from 1.45784 to 1.45449, saving model to MLP.weights.best.hdf5
# Epoch 70/300
#  - 5s - loss: 1.5250 - acc: 0.4589 - val_loss: 1.4522 - val_acc: 0.4948
#
# Epoch 00070: val_loss improved from 1.45449 to 1.45222, saving model to MLP.weights.best.hdf5
# Epoch 71/300
#  - 5s - loss: 1.5217 - acc: 0.4592 - val_loss: 1.4499 - val_acc: 0.4894
#
# Epoch 00071: val_loss improved from 1.45222 to 1.44991, saving model to MLP.weights.best.hdf5
# Epoch 72/300
#  - 5s - loss: 1.5147 - acc: 0.4651 - val_loss: 1.4472 - val_acc: 0.4906
#
# Epoch 00072: val_loss improved from 1.44991 to 1.44718, saving model to MLP.weights.best.hdf5
# Epoch 73/300
#  - 5s - loss: 1.5146 - acc: 0.4621 - val_loss: 1.4455 - val_acc: 0.4948
#
# Epoch 00073: val_loss improved from 1.44718 to 1.44551, saving model to MLP.weights.best.hdf5
# Epoch 74/300
#  - 5s - loss: 1.5148 - acc: 0.4630 - val_loss: 1.4440 - val_acc: 0.4950
#
# Epoch 00074: val_loss improved from 1.44551 to 1.44401, saving model to MLP.weights.best.hdf5
# Epoch 75/300
#  - 5s - loss: 1.5111 - acc: 0.4634 - val_loss: 1.4430 - val_acc: 0.4948
#
# Epoch 00075: val_loss improved from 1.44401 to 1.44304, saving model to MLP.weights.best.hdf5
# Epoch 76/300
#  - 5s - loss: 1.5074 - acc: 0.4652 - val_loss: 1.4385 - val_acc: 0.4952
#
# Epoch 00076: val_loss improved from 1.44304 to 1.43846, saving model to MLP.weights.best.hdf5
# Epoch 77/300
#  - 5s - loss: 1.5091 - acc: 0.4638 - val_loss: 1.4361 - val_acc: 0.4954
#
# Epoch 00077: val_loss improved from 1.43846 to 1.43612, saving model to MLP.weights.best.hdf5
# Epoch 78/300
#  - 5s - loss: 1.5037 - acc: 0.4633 - val_loss: 1.4366 - val_acc: 0.4934
#
# Epoch 00078: val_loss did not improve from 1.43612
# Epoch 79/300
#  - 5s - loss: 1.5033 - acc: 0.4670 - val_loss: 1.4331 - val_acc: 0.4992
#
# Epoch 00079: val_loss improved from 1.43612 to 1.43306, saving model to MLP.weights.best.hdf5
# Epoch 80/300
#  - 6s - loss: 1.4997 - acc: 0.4683 - val_loss: 1.4321 - val_acc: 0.4978
#
# Epoch 00080: val_loss improved from 1.43306 to 1.43208, saving model to MLP.weights.best.hdf5
# Epoch 81/300
#  - 6s - loss: 1.4988 - acc: 0.4701 - val_loss: 1.4308 - val_acc: 0.4990
#
# Epoch 00081: val_loss improved from 1.43208 to 1.43084, saving model to MLP.weights.best.hdf5
# Epoch 82/300
#  - 5s - loss: 1.4950 - acc: 0.4686 - val_loss: 1.4292 - val_acc: 0.4998
#
# Epoch 00082: val_loss improved from 1.43084 to 1.42918, saving model to MLP.weights.best.hdf5
# Epoch 83/300
#  - 5s - loss: 1.4933 - acc: 0.4709 - val_loss: 1.4259 - val_acc: 0.5028
#
# Epoch 00083: val_loss improved from 1.42918 to 1.42591, saving model to MLP.weights.best.hdf5
# Epoch 84/300
#  - 5s - loss: 1.4927 - acc: 0.4717 - val_loss: 1.4246 - val_acc: 0.5010
#
# Epoch 00084: val_loss improved from 1.42591 to 1.42458, saving model to MLP.weights.best.hdf5
# Epoch 85/300
#  - 5s - loss: 1.4880 - acc: 0.4743 - val_loss: 1.4236 - val_acc: 0.4992
#
# Epoch 00085: val_loss improved from 1.42458 to 1.42364, saving model to MLP.weights.best.hdf5
# Epoch 86/300
#  - 5s - loss: 1.4871 - acc: 0.4724 - val_loss: 1.4204 - val_acc: 0.5014
#
# Epoch 00086: val_loss improved from 1.42364 to 1.42041, saving model to MLP.weights.best.hdf5
# Epoch 87/300
#  - 5s - loss: 1.4865 - acc: 0.4738 - val_loss: 1.4197 - val_acc: 0.5022
#
# Epoch 00087: val_loss improved from 1.42041 to 1.41975, saving model to MLP.weights.best.hdf5
# Epoch 88/300
#  - 5s - loss: 1.4881 - acc: 0.4733 - val_loss: 1.4188 - val_acc: 0.5030
#
# Epoch 00088: val_loss improved from 1.41975 to 1.41882, saving model to MLP.weights.best.hdf5
# Epoch 89/300
#  - 5s - loss: 1.4811 - acc: 0.4734 - val_loss: 1.4159 - val_acc: 0.5036
#
# Epoch 00089: val_loss improved from 1.41882 to 1.41593, saving model to MLP.weights.best.hdf5
# Epoch 90/300
#  - 5s - loss: 1.4783 - acc: 0.4741 - val_loss: 1.4148 - val_acc: 0.5014
#
# Epoch 00090: val_loss improved from 1.41593 to 1.41477, saving model to MLP.weights.best.hdf5
# Epoch 91/300
#  - 5s - loss: 1.4768 - acc: 0.4786 - val_loss: 1.4140 - val_acc: 0.5044
#
# Epoch 00091: val_loss improved from 1.41477 to 1.41397, saving model to MLP.weights.best.hdf5
# Epoch 92/300
#  - 5s - loss: 1.4737 - acc: 0.4800 - val_loss: 1.4125 - val_acc: 0.5030
# Epoch 00092: val_loss improved from 1.41397 to 1.41254, saving model to MLP.weights.best.hdf5
# Epoch 93/300
#  - 5s - loss: 1.4762 - acc: 0.4756 - val_loss: 1.4094 - val_acc: 0.5072
#
# Epoch 00093: val_loss improved from 1.41254 to 1.40936, saving model to MLP.weights.best.hdf5
# Epoch 94/300
#  - 5s - loss: 1.4744 - acc: 0.4773 - val_loss: 1.4087 - val_acc: 0.5036
#
# Epoch 00094: val_loss improved from 1.40936 to 1.40873, saving model to MLP.weights.best.hdf5
# Epoch 95/300
#  - 5s - loss: 1.4734 - acc: 0.4777 - val_loss: 1.4074 - val_acc: 0.5058
#
# Epoch 00095: val_loss improved from 1.40873 to 1.40739, saving model to MLP.weights.best.hdf5
# Epoch 96/300
#  - 5s - loss: 1.4654 - acc: 0.4783 - val_loss: 1.4069 - val_acc: 0.5044
#
# Epoch 00096: val_loss improved from 1.40739 to 1.40692, saving model to MLP.weights.best.hdf5
# Epoch 97/300
#  - 5s - loss: 1.4694 - acc: 0.4787 - val_loss: 1.4045 - val_acc: 0.5068
#
# Epoch 00097: val_loss improved from 1.40692 to 1.40455, saving model to MLP.weights.best.hdf5
# Epoch 98/300
#  - 5s - loss: 1.4633 - acc: 0.4814 - val_loss: 1.4017 - val_acc: 0.5060
#
# Epoch 00098: val_loss improved from 1.40455 to 1.40172, saving model to MLP.weights.best.hdf5
# Epoch 99/300
#  - 5s - loss: 1.4633 - acc: 0.4822 - val_loss: 1.4018 - val_acc: 0.5058
#
# Epoch 00099: val_loss did not improve from 1.40172
# Epoch 100/300
#  - 5s - loss: 1.4626 - acc: 0.4811 - val_loss: 1.3979 - val_acc: 0.5108
#
# Epoch 00100: val_loss improved from 1.40172 to 1.39795, saving model to MLP.weights.best.hdf5
# Epoch 101/300
#  - 5s - loss: 1.4627 - acc: 0.4808 - val_loss: 1.3985 - val_acc: 0.5082
#
# Epoch 00101: val_loss did not improve from 1.39795
# Epoch 102/300
#  - 5s - loss: 1.4555 - acc: 0.4842 - val_loss: 1.3968 - val_acc: 0.5082
#
# Epoch 00102: val_loss improved from 1.39795 to 1.39683, saving model to MLP.weights.best.hdf5
# Epoch 103/300
#  - 5s - loss: 1.4539 - acc: 0.4831 - val_loss: 1.3931 - val_acc: 0.5110
#
# Epoch 00103: val_loss improved from 1.39683 to 1.39315, saving model to MLP.weights.best.hdf5
# Epoch 104/300
#  - 5s - loss: 1.4551 - acc: 0.4823 - val_loss: 1.3926 - val_acc: 0.5122
#
# Epoch 00104: val_loss improved from 1.39315 to 1.39265, saving model to MLP.weights.best.hdf5
# Epoch 105/300
#  - 5s - loss: 1.4548 - acc: 0.4842 - val_loss: 1.3908 - val_acc: 0.5106
#
# Epoch 00105: val_loss improved from 1.39265 to 1.39081, saving model to MLP.weights.best.hdf5
# Epoch 106/300
#  - 5s - loss: 1.4485 - acc: 0.4829 - val_loss: 1.3896 - val_acc: 0.5128
#
# Epoch 00106: val_loss improved from 1.39081 to 1.38964, saving model to MLP.weights.best.hdf5
# Epoch 107/300
#  - 5s - loss: 1.4506 - acc: 0.4860 - val_loss: 1.3884 - val_acc: 0.5142
#
# Epoch 00107: val_loss improved from 1.38964 to 1.38836, saving model to MLP.weights.best.hdf5
# Epoch 108/300
#  - 5s - loss: 1.4466 - acc: 0.4846 - val_loss: 1.3874 - val_acc: 0.5132
#
# Epoch 00108: val_loss improved from 1.38836 to 1.38740, saving model to MLP.weights.best.hdf5
# Epoch 109/300
#  - 5s - loss: 1.4467 - acc: 0.4848 - val_loss: 1.3857 - val_acc: 0.5132
#
# Epoch 00109: val_loss improved from 1.38740 to 1.38569, saving model to MLP.weights.best.hdf5
# Epoch 110/300
#  - 5s - loss: 1.4511 - acc: 0.4848 - val_loss: 1.3864 - val_acc: 0.5130
#
# Epoch 00110: val_loss did not improve from 1.38569
# Epoch 111/300
#  - 5s - loss: 1.4387 - acc: 0.4878 - val_loss: 1.3829 - val_acc: 0.5172
#
# Epoch 00111: val_loss improved from 1.38569 to 1.38287, saving model to MLP.weights.best.hdf5
# Epoch 112/300
#  - 5s - loss: 1.4385 - acc: 0.4890 - val_loss: 1.3810 - val_acc: 0.5170
#
# Epoch 00112: val_loss improved from 1.38287 to 1.38103, saving model to MLP.weights.best.hdf5
# Epoch 113/300
#  - 5s - loss: 1.4362 - acc: 0.4889 - val_loss: 1.3807 - val_acc: 0.5132
#
# Epoch 00113: val_loss improved from 1.38103 to 1.38067, saving model to MLP.weights.best.hdf5
# Epoch 114/300
#  - 5s - loss: 1.4329 - acc: 0.4894 - val_loss: 1.3778 - val_acc: 0.5190
#
# Epoch 00114: val_loss improved from 1.38067 to 1.37784, saving model to MLP.weights.best.hdf5
# Epoch 115/300
#  - 5s - loss: 1.4352 - acc: 0.4880 - val_loss: 1.3779 - val_acc: 0.5182
#
# Epoch 00115: val_loss did not improve from 1.37784
# Epoch 116/300
#  - 5s - loss: 1.4355 - acc: 0.4909 - val_loss: 1.3749 - val_acc: 0.5182
#
# Epoch 00116: val_loss improved from 1.37784 to 1.37493, saving model to MLP.weights.best.hdf5
# Epoch 117/300
#  - 5s - loss: 1.4287 - acc: 0.4904 - val_loss: 1.3745 - val_acc: 0.5180
#
# Epoch 00117: val_loss improved from 1.37493 to 1.37452, saving model to MLP.weights.best.hdf5
# Epoch 118/300
#  - 5s - loss: 1.4304 - acc: 0.4912 - val_loss: 1.3727 - val_acc: 0.5190
#
# Epoch 00118: val_loss improved from 1.37452 to 1.37268, saving model to MLP.weights.best.hdf5
# Epoch 119/300
#  - 5s - loss: 1.4298 - acc: 0.4919 - val_loss: 1.3721 - val_acc: 0.5192
#
# Epoch 00119: val_loss improved from 1.37268 to 1.37215, saving model to MLP.weights.best.hdf5
# Epoch 120/300
#  - 5s - loss: 1.4258 - acc: 0.4922 - val_loss: 1.3715 - val_acc: 0.5162
#
# Epoch 00120: val_loss improved from 1.37215 to 1.37154, saving model to MLP.weights.best.hdf5
# Epoch 121/300
#  - 5s - loss: 1.4257 - acc: 0.4936 - val_loss: 1.3698 - val_acc: 0.5190
#
# Epoch 00121: val_loss improved from 1.37154 to 1.36980, saving model to MLP.weights.best.hdf5
# Epoch 122/300
#  - 5s - loss: 1.4250 - acc: 0.4914 - val_loss: 1.3686 - val_acc: 0.5192
#
# Epoch 00122: val_loss improved from 1.36980 to 1.36856, saving model to MLP.weights.best.hdf5
# Epoch 123/300
#  - 5s - loss: 1.4230 - acc: 0.4924 - val_loss: 1.3674 - val_acc: 0.5182
#
# Epoch 00123: val_loss improved from 1.36856 to 1.36742, saving model to MLP.weights.best.hdf5
# Epoch 124/300
#  - 5s - loss: 1.4231 - acc: 0.4951 - val_loss: 1.3671 - val_acc: 0.5190
#
# Epoch 00124: val_loss improved from 1.36742 to 1.36711, saving model to MLP.weights.best.hdf5
# Epoch 125/300
#  - 5s - loss: 1.4206 - acc: 0.4965 - val_loss: 1.3649 - val_acc: 0.5190
#
# Epoch 00125: val_loss improved from 1.36711 to 1.36494, saving model to MLP.weights.best.hdf5
# Epoch 126/300
#  - 5s - loss: 1.4219 - acc: 0.4954 - val_loss: 1.3630 - val_acc: 0.5184
#
# Epoch 00126: val_loss improved from 1.36494 to 1.36298, saving model to MLP.weights.best.hdf5
# Epoch 127/300
#  - 5s - loss: 1.4148 - acc: 0.4953 - val_loss: 1.3620 - val_acc: 0.5214
#
# Epoch 00127: val_loss improved from 1.36298 to 1.36196, saving model to MLP.weights.best.hdf5
# Epoch 128/300
#  - 5s - loss: 1.4182 - acc: 0.4980 - val_loss: 1.3613 - val_acc: 0.5196
#
# Epoch 00128: val_loss improved from 1.36196 to 1.36126, saving model to MLP.weights.best.hdf5
# Epoch 129/300
#  - 5s - loss: 1.4121 - acc: 0.4992 - val_loss: 1.3600 - val_acc: 0.5210
#
# Epoch 00129: val_loss improved from 1.36126 to 1.36000, saving model to MLP.weights.best.hdf5
# Epoch 130/300
#  - 5s - loss: 1.4098 - acc: 0.4991 - val_loss: 1.3579 - val_acc: 0.5230
#
# Epoch 00130: val_loss improved from 1.36000 to 1.35794, saving model to MLP.weights.best.hdf5
# Epoch 131/300
#  - 5s - loss: 1.4036 - acc: 0.4997 - val_loss: 1.3568 - val_acc: 0.5242
#
# Epoch 00131: val_loss improved from 1.35794 to 1.35680, saving model to MLP.weights.best.hdf5
# Epoch 132/300
#  - 5s - loss: 1.4080 - acc: 0.5021 - val_loss: 1.3548 - val_acc: 0.5222
#
# Epoch 00132: val_loss improved from 1.35680 to 1.35482, saving model to MLP.weights.best.hdf5
# Epoch 133/300
#  - 5s - loss: 1.4095 - acc: 0.4984 - val_loss: 1.3529 - val_acc: 0.5264
#
# Epoch 00133: val_loss improved from 1.35482 to 1.35294, saving model to MLP.weights.best.hdf5
# Epoch 134/300
#  - 5s - loss: 1.4110 - acc: 0.4993 - val_loss: 1.3536 - val_acc: 0.5224
#
# Epoch 00134: val_loss did not improve from 1.35294
# Epoch 135/300
#  - 5s - loss: 1.4049 - acc: 0.5015 - val_loss: 1.3533 - val_acc: 0.5200
#
# Epoch 00135: val_loss did not improve from 1.35294
# Epoch 136/300
#  - 5s - loss: 1.4035 - acc: 0.4990 - val_loss: 1.3497 - val_acc: 0.5220
#
# Epoch 00136: val_loss improved from 1.35294 to 1.34970, saving model to MLP.weights.best.hdf5
# Epoch 137/300
#  - 5s - loss: 1.3956 - acc: 0.5037 - val_loss: 1.3486 - val_acc: 0.5250
#
# Epoch 00137: val_loss improved from 1.34970 to 1.34857, saving model to MLP.weights.best.hdf5
# Epoch 138/300
#  - 5s - loss: 1.3991 - acc: 0.5027 - val_loss: 1.3476 - val_acc: 0.5240
#
# Epoch 00138: val_loss improved from 1.34857 to 1.34756, saving model to MLP.weights.best.hdf5
# Epoch 139/300
#  - 5s - loss: 1.3978 - acc: 0.5036 - val_loss: 1.3468 - val_acc: 0.5252
# Epoch 00139: val_loss improved from 1.34756 to 1.34676, saving model to MLP.weights.best.hdf5
# Epoch 140/300
#  - 5s - loss: 1.4006 - acc: 0.5036 - val_loss: 1.3458 - val_acc: 0.5250
#
# Epoch 00140: val_loss improved from 1.34676 to 1.34579, saving model to MLP.weights.best.hdf5
# Epoch 141/300
#  - 5s - loss: 1.3988 - acc: 0.5049 - val_loss: 1.3447 - val_acc: 0.5252
#
# Epoch 00141: val_loss improved from 1.34579 to 1.34471, saving model to MLP.weights.best.hdf5
# Epoch 142/300
#  - 5s - loss: 1.3905 - acc: 0.5041 - val_loss: 1.3424 - val_acc: 0.5264
#
# Epoch 00142: val_loss improved from 1.34471 to 1.34243, saving model to MLP.weights.best.hdf5
# Epoch 143/300
#  - 5s - loss: 1.3886 - acc: 0.5031 - val_loss: 1.3395 - val_acc: 0.5280
#
# Epoch 00143: val_loss improved from 1.34243 to 1.33955, saving model to MLP.weights.best.hdf5
# Epoch 144/300
#  - 5s - loss: 1.3909 - acc: 0.5076 - val_loss: 1.3399 - val_acc: 0.5268
#
# Epoch 00144: val_loss did not improve from 1.33955
# Epoch 145/300
#  - 5s - loss: 1.3923 - acc: 0.5043 - val_loss: 1.3398 - val_acc: 0.5286
#
# Epoch 00145: val_loss did not improve from 1.33955
# Epoch 146/300
#  - 5s - loss: 1.3904 - acc: 0.5045 - val_loss: 1.3395 - val_acc: 0.5282
#
# Epoch 00146: val_loss improved from 1.33955 to 1.33948, saving model to MLP.weights.best.hdf5
# Epoch 147/300
#  - 5s - loss: 1.3833 - acc: 0.5114 - val_loss: 1.3371 - val_acc: 0.5286
#
# Epoch 00147: val_loss improved from 1.33948 to 1.33709, saving model to MLP.weights.best.hdf5
# Epoch 148/300
#  - 5s - loss: 1.3839 - acc: 0.5064 - val_loss: 1.3356 - val_acc: 0.5298
#
# Epoch 00148: val_loss improved from 1.33709 to 1.33562, saving model to MLP.weights.best.hdf5
# Epoch 149/300
#  - 5s - loss: 1.3855 - acc: 0.5075 - val_loss: 1.3361 - val_acc: 0.5284
#
# Epoch 00149: val_loss did not improve from 1.33562
# Epoch 150/300
#  - 5s - loss: 1.3800 - acc: 0.5093 - val_loss: 1.3334 - val_acc: 0.5322
#
# Epoch 00150: val_loss improved from 1.33562 to 1.33342, saving model to MLP.weights.best.hdf5
# Epoch 151/300
#  - 5s - loss: 1.3846 - acc: 0.5046 - val_loss: 1.3336 - val_acc: 0.5300
#
# Epoch 00151: val_loss did not improve from 1.33342
# Epoch 152/300
#  - 5s - loss: 1.3804 - acc: 0.5068 - val_loss: 1.3314 - val_acc: 0.5318
#
# Epoch 00152: val_loss improved from 1.33342 to 1.33139, saving model to MLP.weights.best.hdf5
# Epoch 153/300
#  - 5s - loss: 1.3804 - acc: 0.5092 - val_loss: 1.3334 - val_acc: 0.5290
#
# Epoch 00153: val_loss did not improve from 1.33139
# Epoch 154/300
#  - 5s - loss: 1.3775 - acc: 0.5069 - val_loss: 1.3299 - val_acc: 0.5318
#
# Epoch 00154: val_loss improved from 1.33139 to 1.32992, saving model to MLP.weights.best.hdf5
# Epoch 155/300
#  - 5s - loss: 1.3736 - acc: 0.5101 - val_loss: 1.3301 - val_acc: 0.5286
#
# Epoch 00155: val_loss did not improve from 1.32992
# Epoch 156/300
#  - 5s - loss: 1.3756 - acc: 0.5090 - val_loss: 1.3274 - val_acc: 0.5320
#
# Epoch 00156: val_loss improved from 1.32992 to 1.32744, saving model to MLP.weights.best.hdf5
# Epoch 157/300
#  - 5s - loss: 1.3709 - acc: 0.5115 - val_loss: 1.3273 - val_acc: 0.5320
#
# Epoch 00157: val_loss improved from 1.32744 to 1.32730, saving model to MLP.weights.best.hdf5
# Epoch 158/300
#  - 5s - loss: 1.3685 - acc: 0.5131 - val_loss: 1.3245 - val_acc: 0.5318
#
# Epoch 00158: val_loss improved from 1.32730 to 1.32448, saving model to MLP.weights.best.hdf5
# Epoch 159/300
#  - 5s - loss: 1.3714 - acc: 0.5109 - val_loss: 1.3234 - val_acc: 0.5308
#
# Epoch 00159: val_loss improved from 1.32448 to 1.32339, saving model to MLP.weights.best.hdf5
# Epoch 160/300
#  - 5s - loss: 1.3702 - acc: 0.5130 - val_loss: 1.3231 - val_acc: 0.5336
#
# Epoch 00160: val_loss improved from 1.32339 to 1.32311, saving model to MLP.weights.best.hdf5
# Epoch 161/300
#  - 5s - loss: 1.3671 - acc: 0.5109 - val_loss: 1.3218 - val_acc: 0.5326
#
# Epoch 00161: val_loss improved from 1.32311 to 1.32181, saving model to MLP.weights.best.hdf5
# Epoch 162/300
#  - 5s - loss: 1.3680 - acc: 0.5146 - val_loss: 1.3207 - val_acc: 0.5346
#
# Epoch 00162: val_loss improved from 1.32181 to 1.32069, saving model to MLP.weights.best.hdf5
# Epoch 163/300
#  - 5s - loss: 1.3671 - acc: 0.5130 - val_loss: 1.3224 - val_acc: 0.5334
#
# Epoch 00163: val_loss did not improve from 1.32069
# Epoch 164/300
#  - 5s - loss: 1.3626 - acc: 0.5142 - val_loss: 1.3190 - val_acc: 0.5342
#
# Epoch 00164: val_loss improved from 1.32069 to 1.31896, saving model to MLP.weights.best.hdf5
# Epoch 165/300
#  - 5s - loss: 1.3667 - acc: 0.5149 - val_loss: 1.3186 - val_acc: 0.5356
#
# Epoch 00165: val_loss improved from 1.31896 to 1.31863, saving model to MLP.weights.best.hdf5
# Epoch 166/300
#  - 5s - loss: 1.3604 - acc: 0.5167 - val_loss: 1.3167 - val_acc: 0.5384
#
# Epoch 00166: val_loss improved from 1.31863 to 1.31665, saving model to MLP.weights.best.hdf5
# Epoch 167/300
#  - 5s - loss: 1.3577 - acc: 0.5162 - val_loss: 1.3158 - val_acc: 0.5352
#
# Epoch 00167: val_loss improved from 1.31665 to 1.31581, saving model to MLP.weights.best.hdf5
# Epoch 168/300
#  - 5s - loss: 1.3575 - acc: 0.5139 - val_loss: 1.3147 - val_acc: 0.5366
#
# Epoch 00168: val_loss improved from 1.31581 to 1.31473, saving model to MLP.weights.best.hdf5
# Epoch 169/300
#  - 5s - loss: 1.3596 - acc: 0.5158 - val_loss: 1.3149 - val_acc: 0.5374
#
# Epoch 00169: val_loss did not improve from 1.31473
# Epoch 170/300
#  - 5s - loss: 1.3563 - acc: 0.5169 - val_loss: 1.3126 - val_acc: 0.5392
#
# Epoch 00170: val_loss improved from 1.31473 to 1.31263, saving model to MLP.weights.best.hdf5
# Epoch 171/300
#  - 5s - loss: 1.3528 - acc: 0.5179 - val_loss: 1.3115 - val_acc: 0.5372
#
# Epoch 00171: val_loss improved from 1.31263 to 1.31149, saving model to MLP.weights.best.hdf5
# Epoch 172/300
#  - 5s - loss: 1.3509 - acc: 0.5196 - val_loss: 1.3108 - val_acc: 0.5372
#
# Epoch 00172: val_loss improved from 1.31149 to 1.31083, saving model to MLP.weights.best.hdf5
# Epoch 173/300
#  - 5s - loss: 1.3504 - acc: 0.5196 - val_loss: 1.3081 - val_acc: 0.5382
#
# Epoch 00173: val_loss improved from 1.31083 to 1.30811, saving model to MLP.weights.best.hdf5
# Epoch 174/300
#  - 5s - loss: 1.3504 - acc: 0.5193 - val_loss: 1.3079 - val_acc: 0.5364
#
# Epoch 00174: val_loss improved from 1.30811 to 1.30786, saving model to MLP.weights.best.hdf5
# Epoch 175/300
#  - 5s - loss: 1.3518 - acc: 0.5181 - val_loss: 1.3058 - val_acc: 0.5406
#
# Epoch 00175: val_loss improved from 1.30786 to 1.30578, saving model to MLP.weights.best.hdf5
# Epoch 176/300
#  - 5s - loss: 1.3490 - acc: 0.5179 - val_loss: 1.3055 - val_acc: 0.5400
#
# Epoch 00176: val_loss improved from 1.30578 to 1.30549, saving model to MLP.weights.best.hdf5
# Epoch 177/300
#  - 5s - loss: 1.3469 - acc: 0.5212 - val_loss: 1.3051 - val_acc: 0.5396
#
# Epoch 00177: val_loss improved from 1.30549 to 1.30508, saving model to MLP.weights.best.hdf5
# Epoch 178/300
#  - 5s - loss: 1.3439 - acc: 0.5210 - val_loss: 1.3040 - val_acc: 0.5412
#
# Epoch 00178: val_loss improved from 1.30508 to 1.30398, saving model to MLP.weights.best.hdf5
# Epoch 179/300
#  - 5s - loss: 1.3445 - acc: 0.5233 - val_loss: 1.3030 - val_acc: 0.5416
#
# Epoch 00179: val_loss improved from 1.30398 to 1.30298, saving model to MLP.weights.best.hdf5
# Epoch 180/300
#  - 5s - loss: 1.3475 - acc: 0.5213 - val_loss: 1.3035 - val_acc: 0.5388
#
# Epoch 00180: val_loss did not improve from 1.30298
# Epoch 181/300
#  - 5s - loss: 1.3400 - acc: 0.5216 - val_loss: 1.3019 - val_acc: 0.5406
#
# Epoch 00181: val_loss improved from 1.30298 to 1.30192, saving model to MLP.weights.best.hdf5
# Epoch 182/300
#  - 5s - loss: 1.3407 - acc: 0.5218 - val_loss: 1.3003 - val_acc: 0.5432
#
# Epoch 00182: val_loss improved from 1.30192 to 1.30028, saving model to MLP.weights.best.hdf5
# Epoch 183/300
#  - 5s - loss: 1.3399 - acc: 0.5220 - val_loss: 1.2994 - val_acc: 0.5438
#
# Epoch 00183: val_loss improved from 1.30028 to 1.29936, saving model to MLP.weights.best.hdf5
# Epoch 184/300
#  - 5s - loss: 1.3349 - acc: 0.5235 - val_loss: 1.2996 - val_acc: 0.5436
#
# Epoch 00184: val_loss did not improve from 1.29936
# Epoch 185/300
#  - 5s - loss: 1.3323 - acc: 0.5234 - val_loss: 1.2982 - val_acc: 0.5412
#
# Epoch 00185: val_loss improved from 1.29936 to 1.29819, saving model to MLP.weights.best.hdf5
# Epoch 186/300
#  - 5s - loss: 1.3320 - acc: 0.5252 - val_loss: 1.2980 - val_acc: 0.5446
#
# Epoch 00186: val_loss improved from 1.29819 to 1.29804, saving model to MLP.weights.best.hdf5
# Epoch 187/300
#  - 5s - loss: 1.3308 - acc: 0.5257 - val_loss: 1.2958 - val_acc: 0.5434
# Epoch 00187: val_loss improved from 1.29804 to 1.29584, saving model to MLP.weights.best.hdf5
# Epoch 188/300
#  - 5s - loss: 1.3308 - acc: 0.5265 - val_loss: 1.2953 - val_acc: 0.5452
#
# Epoch 00188: val_loss improved from 1.29584 to 1.29530, saving model to MLP.weights.best.hdf5
# Epoch 189/300
#  - 5s - loss: 1.3327 - acc: 0.5237 - val_loss: 1.2952 - val_acc: 0.5452
#
# Epoch 00189: val_loss improved from 1.29530 to 1.29516, saving model to MLP.weights.best.hdf5
# Epoch 190/300
#  - 5s - loss: 1.3308 - acc: 0.5245 - val_loss: 1.2939 - val_acc: 0.5452
#
# Epoch 00190: val_loss improved from 1.29516 to 1.29391, saving model to MLP.weights.best.hdf5
# Epoch 191/300
#  - 5s - loss: 1.3282 - acc: 0.5264 - val_loss: 1.2936 - val_acc: 0.5444
#
# Epoch 00191: val_loss improved from 1.29391 to 1.29357, saving model to MLP.weights.best.hdf5
# Epoch 192/300
#  - 5s - loss: 1.3245 - acc: 0.5260 - val_loss: 1.2917 - val_acc: 0.5446
#
# Epoch 00192: val_loss improved from 1.29357 to 1.29174, saving model to MLP.weights.best.hdf5
# Epoch 193/300
#  - 5s - loss: 1.3330 - acc: 0.5257 - val_loss: 1.2917 - val_acc: 0.5468
#
# Epoch 00193: val_loss improved from 1.29174 to 1.29172, saving model to MLP.weights.best.hdf5
# Epoch 194/300
#  - 5s - loss: 1.3319 - acc: 0.5268 - val_loss: 1.2904 - val_acc: 0.5452
#
# Epoch 00194: val_loss improved from 1.29172 to 1.29038, saving model to MLP.weights.best.hdf5
# Epoch 195/300
#  - 5s - loss: 1.3242 - acc: 0.5290 - val_loss: 1.2901 - val_acc: 0.5472
#
# Epoch 00195: val_loss improved from 1.29038 to 1.29013, saving model to MLP.weights.best.hdf5
# Epoch 196/300
#  - 5s - loss: 1.3193 - acc: 0.5276 - val_loss: 1.2880 - val_acc: 0.5466
#
# Epoch 00196: val_loss improved from 1.29013 to 1.28802, saving model to MLP.weights.best.hdf5
# Epoch 197/300
#  - 5s - loss: 1.3238 - acc: 0.5286 - val_loss: 1.2887 - val_acc: 0.5448
#
# Epoch 00197: val_loss did not improve from 1.28802
# Epoch 198/300
#  - 5s - loss: 1.3197 - acc: 0.5262 - val_loss: 1.2869 - val_acc: 0.5476
#
# Epoch 00198: val_loss improved from 1.28802 to 1.28690, saving model to MLP.weights.best.hdf5
# Epoch 199/300
#  - 5s - loss: 1.3201 - acc: 0.5292 - val_loss: 1.2863 - val_acc: 0.5486
#
# Epoch 00199: val_loss improved from 1.28690 to 1.28631, saving model to MLP.weights.best.hdf5
# Epoch 200/300
#  - 5s - loss: 1.3213 - acc: 0.5298 - val_loss: 1.2855 - val_acc: 0.5442
#
# Epoch 00200: val_loss improved from 1.28631 to 1.28550, saving model to MLP.weights.best.hdf5
# Epoch 201/300
#  - 5s - loss: 1.3151 - acc: 0.5309 - val_loss: 1.2838 - val_acc: 0.5490
#
# Epoch 00201: val_loss improved from 1.28550 to 1.28378, saving model to MLP.weights.best.hdf5
# Epoch 202/300
#  - 5s - loss: 1.3143 - acc: 0.5322 - val_loss: 1.2838 - val_acc: 0.5462
#
# Epoch 00202: val_loss improved from 1.28378 to 1.28378, saving model to MLP.weights.best.hdf5
# Epoch 203/300
#  - 5s - loss: 1.3138 - acc: 0.5321 - val_loss: 1.2841 - val_acc: 0.5474
#
# Epoch 00203: val_loss did not improve from 1.28378
# Epoch 204/300
#  - 5s - loss: 1.3099 - acc: 0.5325 - val_loss: 1.2815 - val_acc: 0.5498
#
# Epoch 00204: val_loss improved from 1.28378 to 1.28154, saving model to MLP.weights.best.hdf5
# Epoch 205/300
#  - 5s - loss: 1.3105 - acc: 0.5322 - val_loss: 1.2807 - val_acc: 0.5492
#
# Epoch 00205: val_loss improved from 1.28154 to 1.28068, saving model to MLP.weights.best.hdf5
# Epoch 206/300
#  - 5s - loss: 1.3135 - acc: 0.5308 - val_loss: 1.2819 - val_acc: 0.5482
#
# Epoch 00206: val_loss did not improve from 1.28068
# Epoch 207/300
#  - 5s - loss: 1.3126 - acc: 0.5311 - val_loss: 1.2791 - val_acc: 0.5508
#
# Epoch 00207: val_loss improved from 1.28068 to 1.27910, saving model to MLP.weights.best.hdf5
# Epoch 208/300
#  - 5s - loss: 1.3090 - acc: 0.5344 - val_loss: 1.2805 - val_acc: 0.5468
#
# Epoch 00208: val_loss did not improve from 1.27910
# Epoch 209/300
#  - 5s - loss: 1.3088 - acc: 0.5323 - val_loss: 1.2796 - val_acc: 0.5512
#
# Epoch 00209: val_loss did not improve from 1.27910
# Epoch 210/300
#  - 5s - loss: 1.3089 - acc: 0.5313 - val_loss: 1.2760 - val_acc: 0.5514
#
# Epoch 00210: val_loss improved from 1.27910 to 1.27603, saving model to MLP.weights.best.hdf5
# Epoch 211/300
#  - 5s - loss: 1.3056 - acc: 0.5343 - val_loss: 1.2767 - val_acc: 0.5516
#
# Epoch 00211: val_loss did not improve from 1.27603
# Epoch 212/300
#  - 5s - loss: 1.3054 - acc: 0.5347 - val_loss: 1.2756 - val_acc: 0.5532
#
# Epoch 00212: val_loss improved from 1.27603 to 1.27558, saving model to MLP.weights.best.hdf5
# Epoch 213/300
#  - 5s - loss: 1.3035 - acc: 0.5360 - val_loss: 1.2740 - val_acc: 0.5536
#
# Epoch 00213: val_loss improved from 1.27558 to 1.27399, saving model to MLP.weights.best.hdf5
# Epoch 214/300
#  - 5s - loss: 1.3004 - acc: 0.5346 - val_loss: 1.2747 - val_acc: 0.5530
#
# Epoch 00214: val_loss did not improve from 1.27399
# Epoch 215/300
#  - 5s - loss: 1.2957 - acc: 0.5346 - val_loss: 1.2742 - val_acc: 0.5528
#
# Epoch 00215: val_loss did not improve from 1.27399
# Epoch 216/300
#  - 5s - loss: 1.3018 - acc: 0.5337 - val_loss: 1.2734 - val_acc: 0.5532
#
# Epoch 00216: val_loss improved from 1.27399 to 1.27343, saving model to MLP.weights.best.hdf5
# Epoch 217/300
#  - 5s - loss: 1.2977 - acc: 0.5362 - val_loss: 1.2739 - val_acc: 0.5514
#
# Epoch 00217: val_loss did not improve from 1.27343
# Epoch 218/300
#  - 5s - loss: 1.2906 - acc: 0.5413 - val_loss: 1.2714 - val_acc: 0.5506
#
# Epoch 00218: val_loss improved from 1.27343 to 1.27139, saving model to MLP.weights.best.hdf5
# Epoch 219/300
#  - 5s - loss: 1.3008 - acc: 0.5381 - val_loss: 1.2700 - val_acc: 0.5546
#
# Epoch 00219: val_loss improved from 1.27139 to 1.27000, saving model to MLP.weights.best.hdf5
# Epoch 220/300
#  - 5s - loss: 1.2945 - acc: 0.5412 - val_loss: 1.2696 - val_acc: 0.5530
#
# Epoch 00220: val_loss improved from 1.27000 to 1.26959, saving model to MLP.weights.best.hdf5
# Epoch 221/300
#  - 5s - loss: 1.2928 - acc: 0.5382 - val_loss: 1.2682 - val_acc: 0.5552
#
# Epoch 00221: val_loss improved from 1.26959 to 1.26818, saving model to MLP.weights.best.hdf5
# Epoch 222/300
#  - 5s - loss: 1.2964 - acc: 0.5392 - val_loss: 1.2706 - val_acc: 0.5496
#
# Epoch 00222: val_loss did not improve from 1.26818
# Epoch 223/300
#  - 5s - loss: 1.2942 - acc: 0.5379 - val_loss: 1.2672 - val_acc: 0.5518
#
# Epoch 00223: val_loss improved from 1.26818 to 1.26716, saving model to MLP.weights.best.hdf5
# Epoch 224/300
#  - 5s - loss: 1.2861 - acc: 0.5429 - val_loss: 1.2660 - val_acc: 0.5536
#
# Epoch 00224: val_loss improved from 1.26716 to 1.26604, saving model to MLP.weights.best.hdf5
# Epoch 225/300
#  - 5s - loss: 1.2893 - acc: 0.5399 - val_loss: 1.2650 - val_acc: 0.5532
#
# Epoch 00225: val_loss improved from 1.26604 to 1.26498, saving model to MLP.weights.best.hdf5
# Epoch 226/300
#  - 5s - loss: 1.2899 - acc: 0.5428 - val_loss: 1.2656 - val_acc: 0.5514
#
# Epoch 00226: val_loss did not improve from 1.26498
# Epoch 227/300
#  - 5s - loss: 1.2845 - acc: 0.5377 - val_loss: 1.2653 - val_acc: 0.5522
#
# Epoch 00227: val_loss did not improve from 1.26498
# Epoch 228/300
#  - 5s - loss: 1.2806 - acc: 0.5434 - val_loss: 1.2658 - val_acc: 0.5508
#
# Epoch 00228: val_loss did not improve from 1.26498
# Epoch 229/300
#  - 5s - loss: 1.2863 - acc: 0.5407 - val_loss: 1.2626 - val_acc: 0.5500
#
# Epoch 00229: val_loss improved from 1.26498 to 1.26259, saving model to MLP.weights.best.hdf5
# Epoch 230/300
#  - 5s - loss: 1.2873 - acc: 0.5422 - val_loss: 1.2629 - val_acc: 0.5550
#
# Epoch 00230: val_loss did not improve from 1.26259
# Epoch 231/300
#  - 5s - loss: 1.2859 - acc: 0.5416 - val_loss: 1.2623 - val_acc: 0.5522
#
# Epoch 00231: val_loss improved from 1.26259 to 1.26229, saving model to MLP.weights.best.hdf5
# Epoch 232/300
#  - 5s - loss: 1.2837 - acc: 0.5401 - val_loss: 1.2611 - val_acc: 0.5542
#
# Epoch 00232: val_loss improved from 1.26229 to 1.26107, saving model to MLP.weights.best.hdf5
# Epoch 233/300
#  - 5s - loss: 1.2758 - acc: 0.5424 - val_loss: 1.2592 - val_acc: 0.5580
#
# Epoch 00233: val_loss improved from 1.26107 to 1.25922, saving model to MLP.weights.best.hdf5
# Epoch 234/300
#  - 5s - loss: 1.2805 - acc: 0.5433 - val_loss: 1.2593 - val_acc: 0.5564
#
# Epoch 00234: val_loss did not improve from 1.25922
# Epoch 235/300
#  - 5s - loss: 1.2811 - acc: 0.5433 - val_loss: 1.2588 - val_acc: 0.5568
#
# Epoch 00235: val_loss improved from 1.25922 to 1.25883, saving model to MLP.weights.best.hdf5
# Epoch 236/300
#  - 5s - loss: 1.2728 - acc: 0.5459 - val_loss: 1.2579 - val_acc: 0.5556
# Epoch 00236: val_loss improved from 1.25883 to 1.25794, saving model to MLP.weights.best.hdf5
# Epoch 237/300
#  - 5s - loss: 1.2775 - acc: 0.5421 - val_loss: 1.2571 - val_acc: 0.5578
#
# Epoch 00237: val_loss improved from 1.25794 to 1.25711, saving model to MLP.weights.best.hdf5
# Epoch 238/300
#  - 5s - loss: 1.2744 - acc: 0.5456 - val_loss: 1.2571 - val_acc: 0.5544
#
# Epoch 00238: val_loss did not improve from 1.25711
# Epoch 239/300
#  - 5s - loss: 1.2740 - acc: 0.5442 - val_loss: 1.2560 - val_acc: 0.5586
#
# Epoch 00239: val_loss improved from 1.25711 to 1.25604, saving model to MLP.weights.best.hdf5
# Epoch 240/300
#  - 5s - loss: 1.2713 - acc: 0.5446 - val_loss: 1.2564 - val_acc: 0.5544
#
# Epoch 00240: val_loss did not improve from 1.25604
# Epoch 241/300
#  - 5s - loss: 1.2748 - acc: 0.5466 - val_loss: 1.2555 - val_acc: 0.5558
#
# Epoch 00241: val_loss improved from 1.25604 to 1.25546, saving model to MLP.weights.best.hdf5
# Epoch 242/300
#  - 5s - loss: 1.2728 - acc: 0.5457 - val_loss: 1.2539 - val_acc: 0.5566
#
# Epoch 00242: val_loss improved from 1.25546 to 1.25392, saving model to MLP.weights.best.hdf5
# Epoch 243/300
#  - 5s - loss: 1.2678 - acc: 0.5491 - val_loss: 1.2547 - val_acc: 0.5556
#
# Epoch 00243: val_loss did not improve from 1.25392
# Epoch 244/300
#  - 5s - loss: 1.2693 - acc: 0.5475 - val_loss: 1.2545 - val_acc: 0.5546
#
# Epoch 00244: val_loss did not improve from 1.25392
# Epoch 245/300
#  - 5s - loss: 1.2651 - acc: 0.5465 - val_loss: 1.2519 - val_acc: 0.5602
#
# Epoch 00245: val_loss improved from 1.25392 to 1.25191, saving model to MLP.weights.best.hdf5
# Epoch 246/300
#  - 5s - loss: 1.2681 - acc: 0.5463 - val_loss: 1.2515 - val_acc: 0.5574
#
# Epoch 00246: val_loss improved from 1.25191 to 1.25152, saving model to MLP.weights.best.hdf5
# Epoch 247/300
#  - 5s - loss: 1.2666 - acc: 0.5481 - val_loss: 1.2514 - val_acc: 0.5550
#
# Epoch 00247: val_loss improved from 1.25152 to 1.25139, saving model to MLP.weights.best.hdf5
# Epoch 248/300
#  - 5s - loss: 1.2712 - acc: 0.5448 - val_loss: 1.2510 - val_acc: 0.5596
#
# Epoch 00248: val_loss improved from 1.25139 to 1.25102, saving model to MLP.weights.best.hdf5
# Epoch 249/300
#  - 5s - loss: 1.2630 - acc: 0.5486 - val_loss: 1.2504 - val_acc: 0.5592
#
# Epoch 00249: val_loss improved from 1.25102 to 1.25043, saving model to MLP.weights.best.hdf5
# Epoch 250/300
#  - 5s - loss: 1.2644 - acc: 0.5477 - val_loss: 1.2481 - val_acc: 0.5586
#
# Epoch 00250: val_loss improved from 1.25043 to 1.24815, saving model to MLP.weights.best.hdf5
# Epoch 251/300
#  - 5s - loss: 1.2646 - acc: 0.5489 - val_loss: 1.2477 - val_acc: 0.5606
#
# Epoch 00251: val_loss improved from 1.24815 to 1.24770, saving model to MLP.weights.best.hdf5
# Epoch 252/300
#  - 5s - loss: 1.2568 - acc: 0.5520 - val_loss: 1.2486 - val_acc: 0.5568
#
# Epoch 00252: val_loss did not improve from 1.24770
# Epoch 253/300
#  - 5s - loss: 1.2654 - acc: 0.5479 - val_loss: 1.2487 - val_acc: 0.5594
#
# Epoch 00253: val_loss did not improve from 1.24770
# Epoch 254/300
#  - 5s - loss: 1.2603 - acc: 0.5494 - val_loss: 1.2461 - val_acc: 0.5584
#
# Epoch 00254: val_loss improved from 1.24770 to 1.24614, saving model to MLP.weights.best.hdf5
# Epoch 255/300
#  - 5s - loss: 1.2608 - acc: 0.5493 - val_loss: 1.2448 - val_acc: 0.5626
#
# Epoch 00255: val_loss improved from 1.24614 to 1.24476, saving model to MLP.weights.best.hdf5
# Epoch 256/300
#  - 5s - loss: 1.2545 - acc: 0.5514 - val_loss: 1.2456 - val_acc: 0.5608
#
# Epoch 00256: val_loss did not improve from 1.24476
# Epoch 257/300
#  - 5s - loss: 1.2505 - acc: 0.5531 - val_loss: 1.2435 - val_acc: 0.5622
#
# Epoch 00257: val_loss improved from 1.24476 to 1.24351, saving model to MLP.weights.best.hdf5
# Epoch 258/300
#  - 5s - loss: 1.2551 - acc: 0.5500 - val_loss: 1.2426 - val_acc: 0.5594
#
# Epoch 00258: val_loss improved from 1.24351 to 1.24257, saving model to MLP.weights.best.hdf5
# Epoch 259/300
#  - 5s - loss: 1.2501 - acc: 0.5507 - val_loss: 1.2436 - val_acc: 0.5602
#
# Epoch 00259: val_loss did not improve from 1.24257
# Epoch 260/300
#  - 5s - loss: 1.2528 - acc: 0.5498 - val_loss: 1.2427 - val_acc: 0.5616
#
# Epoch 00260: val_loss did not improve from 1.24257
# Epoch 261/300
#  - 5s - loss: 1.2518 - acc: 0.5543 - val_loss: 1.2433 - val_acc: 0.5614
#
# Epoch 00261: val_loss did not improve from 1.24257
# Epoch 262/300
#  - 5s - loss: 1.2527 - acc: 0.5528 - val_loss: 1.2420 - val_acc: 0.5600
#
# Epoch 00262: val_loss improved from 1.24257 to 1.24197, saving model to MLP.weights.best.hdf5
# Epoch 263/300
#  - 5s - loss: 1.2506 - acc: 0.5503 - val_loss: 1.2415 - val_acc: 0.5620
#
# Epoch 00263: val_loss improved from 1.24197 to 1.24151, saving model to MLP.weights.best.hdf5
# Epoch 264/300
#  - 5s - loss: 1.2474 - acc: 0.5540 - val_loss: 1.2406 - val_acc: 0.5608
#
# Epoch 00264: val_loss improved from 1.24151 to 1.24058, saving model to MLP.weights.best.hdf5
# Epoch 265/300
#  - 5s - loss: 1.2450 - acc: 0.5547 - val_loss: 1.2400 - val_acc: 0.5644
#
# Epoch 00265: val_loss improved from 1.24058 to 1.24000, saving model to MLP.weights.best.hdf5
# Epoch 266/300
#  - 5s - loss: 1.2473 - acc: 0.5540 - val_loss: 1.2406 - val_acc: 0.5610
#
# Epoch 00266: val_loss did not improve from 1.24000
# Epoch 267/300
#  - 5s - loss: 1.2479 - acc: 0.5525 - val_loss: 1.2400 - val_acc: 0.5630
#
# Epoch 00267: val_loss improved from 1.24000 to 1.23997, saving model to MLP.weights.best.hdf5
# Epoch 268/300
#  - 5s - loss: 1.2488 - acc: 0.5538 - val_loss: 1.2382 - val_acc: 0.5630
#
# Epoch 00268: val_loss improved from 1.23997 to 1.23822, saving model to MLP.weights.best.hdf5
# Epoch 269/300
#  - 5s - loss: 1.2420 - acc: 0.5563 - val_loss: 1.2363 - val_acc: 0.5626
#
# Epoch 00269: val_loss improved from 1.23822 to 1.23634, saving model to MLP.weights.best.hdf5
# Epoch 270/300
#  - 5s - loss: 1.2426 - acc: 0.5573 - val_loss: 1.2379 - val_acc: 0.5612
#
# Epoch 00270: val_loss did not improve from 1.23634
# Epoch 271/300
#  - 5s - loss: 1.2481 - acc: 0.5563 - val_loss: 1.2373 - val_acc: 0.5630
#
# Epoch 00271: val_loss did not improve from 1.23634
# Epoch 272/300
#  - 5s - loss: 1.2400 - acc: 0.5566 - val_loss: 1.2361 - val_acc: 0.5598
#
# Epoch 00272: val_loss improved from 1.23634 to 1.23609, saving model to MLP.weights.best.hdf5
# Epoch 273/300
#  - 5s - loss: 1.2396 - acc: 0.5553 - val_loss: 1.2338 - val_acc: 0.5656
#
# Epoch 00273: val_loss improved from 1.23609 to 1.23378, saving model to MLP.weights.best.hdf5
# Epoch 274/300
#  - 5s - loss: 1.2387 - acc: 0.5568 - val_loss: 1.2349 - val_acc: 0.5644
#
# Epoch 00274: val_loss did not improve from 1.23378
# Epoch 275/300
#  - 5s - loss: 1.2378 - acc: 0.5570 - val_loss: 1.2337 - val_acc: 0.5644
#
# Epoch 00275: val_loss improved from 1.23378 to 1.23368, saving model to MLP.weights.best.hdf5
# Epoch 276/300
#  - 5s - loss: 1.2388 - acc: 0.5542 - val_loss: 1.2333 - val_acc: 0.5644
#
# Epoch 00276: val_loss improved from 1.23368 to 1.23326, saving model to MLP.weights.best.hdf5
# Epoch 277/300
#  - 5s - loss: 1.2391 - acc: 0.5581 - val_loss: 1.2325 - val_acc: 0.5638
#
# Epoch 00277: val_loss improved from 1.23326 to 1.23253, saving model to MLP.weights.best.hdf5
# Epoch 278/300
#  - 5s - loss: 1.2337 - acc: 0.5597 - val_loss: 1.2327 - val_acc: 0.5634
#
# Epoch 00278: val_loss did not improve from 1.23253
# Epoch 279/300
#  - 5s - loss: 1.2396 - acc: 0.5584 - val_loss: 1.2309 - val_acc: 0.5670
#
# Epoch 00279: val_loss improved from 1.23253 to 1.23086, saving model to MLP.weights.best.hdf5
# Epoch 280/300
#  - 5s - loss: 1.2316 - acc: 0.5570 - val_loss: 1.2317 - val_acc: 0.5632
#
# Epoch 00280: val_loss did not improve from 1.23086
# Epoch 281/300
#  - 5s - loss: 1.2388 - acc: 0.5581 - val_loss: 1.2306 - val_acc: 0.5652
#
# Epoch 00281: val_loss improved from 1.23086 to 1.23058, saving model to MLP.weights.best.hdf5
# Epoch 282/300
#  - 5s - loss: 1.2330 - acc: 0.5620 - val_loss: 1.2299 - val_acc: 0.5662
#
# Epoch 00282: val_loss improved from 1.23058 to 1.22985, saving model to MLP.weights.best.hdf5
# Epoch 283/300
#  - 5s - loss: 1.2335 - acc: 0.5584 - val_loss: 1.2289 - val_acc: 0.5684
#
# Epoch 00283: val_loss improved from 1.22985 to 1.22894, saving model to MLP.weights.best.hdf5
# Epoch 284/300
#  - 5s - loss: 1.2286 - acc: 0.5610 - val_loss: 1.2282 - val_acc: 0.5670
#
# Epoch 00284: val_loss improved from 1.22894 to 1.22823, saving model to MLP.weights.best.hdf5
# Epoch 285/300
#  - 5s - loss: 1.2330 - acc: 0.5590 - val_loss: 1.2301 - val_acc: 0.5612
#
# Epoch 00285: val_loss did not improve from 1.22823
# Epoch 286/300
#  - 5s - loss: 1.2320 - acc: 0.5602 - val_loss: 1.2283 - val_acc: 0.5648
#
# Epoch 00286: val_loss did not improve from 1.22823
# Epoch 287/300
#  - 5s - loss: 1.2288 - acc: 0.5602 - val_loss: 1.2280 - val_acc: 0.5654
#
# Epoch 00287: val_loss improved from 1.22823 to 1.22798, saving model to MLP.weights.best.hdf5
# Epoch 288/300
#  - 5s - loss: 1.2281 - acc: 0.5603 - val_loss: 1.2282 - val_acc: 0.5648
#
# Epoch 00288: val_loss did not improve from 1.22798
# Epoch 289/300
#  - 5s - loss: 1.2269 - acc: 0.5628 - val_loss: 1.2262 - val_acc: 0.5678
#
# Epoch 00289: val_loss improved from 1.22798 to 1.22619, saving model to MLP.weights.best.hdf5
# Epoch 290/300
#  - 5s - loss: 1.2330 - acc: 0.5584 - val_loss: 1.2271 - val_acc: 0.5670
#
# Epoch 00290: val_loss did not improve from 1.22619
# Epoch 291/300
#  - 5s - loss: 1.2226 - acc: 0.5615 - val_loss: 1.2263 - val_acc: 0.5668
#
# Epoch 00291: val_loss did not improve from 1.22619
# Epoch 292/300
#  - 5s - loss: 1.2211 - acc: 0.5622 - val_loss: 1.2273 - val_acc: 0.5674
#
# Epoch 00292: val_loss did not improve from 1.22619
# Epoch 293/300
#  - 5s - loss: 1.2248 - acc: 0.5602 - val_loss: 1.2250 - val_acc: 0.5696
#
# Epoch 00293: val_loss improved from 1.22619 to 1.22502, saving model to MLP.weights.best.hdf5
# Epoch 294/300
#  - 5s - loss: 1.2243 - acc: 0.5630 - val_loss: 1.2248 - val_acc: 0.5696
#
# Epoch 00294: val_loss improved from 1.22502 to 1.22483, saving model to MLP.weights.best.hdf5
# Epoch 295/300
#  - 5s - loss: 1.2232 - acc: 0.5609 - val_loss: 1.2251 - val_acc: 0.5682
#
# Epoch 00295: val_loss did not improve from 1.22483
# Epoch 296/300
#  - 5s - loss: 1.2210 - acc: 0.5672 - val_loss: 1.2232 - val_acc: 0.5678
#
# Epoch 00296: val_loss improved from 1.22483 to 1.22315, saving model to MLP.weights.best.hdf5
# Epoch 297/300
#  - 5s - loss: 1.2232 - acc: 0.5625 - val_loss: 1.2231 - val_acc: 0.5688
#
# Epoch 00297: val_loss improved from 1.22315 to 1.22314, saving model to MLP.weights.best.hdf5
# Epoch 298/300
#  - 5s - loss: 1.2191 - acc: 0.5624 - val_loss: 1.2231 - val_acc: 0.5652
#
# Epoch 00298: val_loss improved from 1.22314 to 1.22310, saving model to MLP.weights.best.hdf5
# Epoch 299/300
#  - 5s - loss: 1.2139 - acc: 0.5646 - val_loss: 1.2213 - val_acc: 0.5722
#
# Epoch 00299: val_loss improved from 1.22310 to 1.22132, saving model to MLP.weights.best.hdf5
# Epoch 300/300
#  - 5s - loss: 1.2165 - acc: 0.5655 - val_loss: 1.2238 - val_acc: 0.5666
#
# Epoch 00300: val_loss did not improve from 1.22132

# %% [markdown]
# # MLP: Model Evaluat. with the weights that gaving best validat. accuracy

# %%
#model saved to 'MLP.weights.best.hdf5'
MLP.load_weights('MLP.weights.best.hdf5')
loss,test_accuracy = MLP.evaluate(x_test, y_test)
print('\n', 'Loss value' ,loss)
print('\n', 'Testing Accuracy' ,test_accuracy)
# Out:
# 10000/10000 [==============================] - 1s 76us/step
#
#  Loss value 1.229475283050537
#
#  Testing Accuracy 0.5596

# %%
# get predictions on the test set
y_pred = MLP.predict(x_test)

# %%
figure = plt.figure(figsize=(20, 8))
for i, x in enumerate(np.random.choice(10000, size=40)):
    img = figure.add_subplot(5, 8, i + 1, xticks=[], yticks=[])
    img.imshow(np.squeeze(aaa[x]))
    pred_id = np.argmax(y_pred[x])
    true_id = np.argmax(y_test[x])
    img.set_title("{} ({})".format(ten[pred_id], ten[true_id]),color=("darkgreen" if pred_id == true_id else "red"))

# %% [markdown]
# # MLP: Prediction Visualisation

# %% [markdown]
# # Visualisation

# %%
#model saved to 'MLP.weights.best.hdf5'
MLP.load_weights('MLP.weights.best.hdf5')
loss,test_accuracy = MLP.evaluate(x_test, y_test)
print('\n', 'Loss value' ,loss)
print('\n', 'Testing Accuracy' ,test_accuracy)

# summarize history for accuracy
plt.plot(History.history['acc'])
plt.plot(History.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# 10000/10000 [==============================] - 1s 79us/step
#
#  Loss value 1.229475283050537
#
#  Testing Accuracy 0.5596

# %%
accuracy_length = len(History.history['acc']) 
length_val_accuracy = len(History.history['val_acc'])
loss_length = len(History.history['loss'])
length_val_accuracy = len(History.history['val_loss'])

# Visualize the reults
#fig, axs = plt.subplots(1, 2, figsize=(15, 5))

# Accuracy during training
plt.plot(range(1, accuracy_length + 1), History.history['acc'])
plt.plot(range(1, length_val_accuracy + 1), History.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='best')
plt.show()
# Loss during training
plt.plot(range(1, loss_length +1), History.history['loss'])
plt.plot(range(1, length_val_accuracy +1), History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='best')
plt.show()
