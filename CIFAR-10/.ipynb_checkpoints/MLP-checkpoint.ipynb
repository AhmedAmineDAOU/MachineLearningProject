# %% [markdown]
# # Multilayer perceptron on CIFAR-10

# %% [markdown]
# ## Imports

# %%
import keras
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.callbacks import ModelCheckpoint   
from sklearn.preprocessing import Imputer, MinMaxScaler
from sklearn.decomposition import PCA


import sys

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

stdout = sys.stdout
sys.stdout = open('/dev/null', 'w')
sys.stdout = stdout

# %% [markdown]
# ## Loading Data & printing shapes

# %%
# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print("trainig data shape  : ",x_train.shape)
print("trainig labels shape: ",y_train.shape)

print("testing data shape  : ",x_test.shape)
print("testing labels shape: ",y_test.shape)
# Out:
# trainig data shape  :  (50000, 32, 32, 3)
# trainig labels shape:  (50000, 1)
# testing data shape  :  (10000, 32, 32, 3)
# testing labels shape:  (10000, 1)

# %% [markdown]
# ## Data exploration
# First data visualisation without any pre-processing on it.
# Printing 10 first images from the training set.

# %%
figure1 = plt.figure(figsize=(15,5))
for i in range(1,11):
    images = figure1.add_subplot(2, 5, i , xticks=[], yticks=[])
    images.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ## Data normalization

# %%
x_train = x_train.astype('float32')/255
x_test  = x_test.astype('float32')/255

# %%
#**********************should reshape and apply PCA ******************************

# %%
#from time import time as runtime
#t = runtime()
#pca = PCA(n_components=100)
#pca.fit(x_train)
#print("training PCA on training set takes: %.1f" % (runtime()-t))
#t = runtime()
#x_train = pca.transform(x_train)
#x_test = pca.transform(x_test)
#print("Transforming training & testing set takes: %.1f" % (runtime()-t))

# %% [markdown]
# ## Labels onehote Encoding & Spliting Testing data into training (90%) /Validation (10%)

# %%
# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
ten = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
len(ten)
# encoding labels to onehot

y_train = keras.utils.to_categorical(y_train, len(ten))
y_test  = keras.utils.to_categorical(y_test, len(ten))
print("[after onehote encoding]")
print("trainig labels shape: ",y_train.shape)
print("testing labels shape: ",y_test.shape,"\n")

# training set spliting into training (45000) and validation (5000) sets
(x_train, x_validation) = x_train[5000:], x_train[:5000]
(y_train, y_validation) = y_train[5000:], y_train[:5000]

print("[after spliting]")
print("trainig   data shape  : ",x_train.shape ,x_train.shape[0], 'examples')
print("validation data shape : ",x_validation.shape," ",x_validation.shape[0],  'examples')
print("testing   data shape  : ",x_test.shape,x_test.shape[0], 'examples')
# Out:
# [after onehote encoding]
# trainig labels shape:  (50000, 10)
# testing labels shape:  (10000, 10)
#
# [after spliting]
# trainig   data shape  :  (45000, 32, 32, 3) 45000 examples
# validation data shape :  (5000, 32, 32, 3)   5000 examples
# testing   data shape  :  (10000, 32, 32, 3) 10000 examples

# %% [markdown]
# # MLP: Multilayer Perceptron Definition
# https://keras.io/getting-started/sequential-model-guide/

# %%
#creating a sequential model &passing a list of layers instances to it

MLP = Sequential([ Flatten(input_shape = x_train.shape[1:]),
                   Dense(1000, activation='relu'),#a fully-connected layer with 1000 hidden units
                   Dropout(0.2),                  #helps prevent overfitting.
                   Dense(512, activation='relu'), #a fully-connected layer with 512 hidden units
                   Dropout(0.2),                  #helps prevent overfitting
                   Dense(len(ten), activation='softmax')])#a fully-connected layer with 10 hidden units
MLP.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              3073000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               512512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 3,590,642
# Trainable params: 3,590,642
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # MLP: Compiling the model

# %%
MLP.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# # Training our MLP

# %%
checkpointer = ModelCheckpoint(filepath='MLP.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
History = MLP.fit(x_train, y_train, batch_size=200, epochs=20,
          validation_data=(x_validation, y_validation), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/20
#  - 26s - loss: 3.1709 - acc: 0.2175 - val_loss: 1.9069 - val_acc: 0.3048
#
# Epoch 00001: val_loss improved from inf to 1.90688, saving model to MLP.weights.best.hdf5
# Epoch 2/20
#  - 27s - loss: 1.9045 - acc: 0.3109 - val_loss: 1.8490 - val_acc: 0.3370
#
# Epoch 00002: val_loss improved from 1.90688 to 1.84897, saving model to MLP.weights.best.hdf5
# Epoch 3/20
#  - 30s - loss: 1.8175 - acc: 0.3492 - val_loss: 1.6857 - val_acc: 0.4050
#
# Epoch 00003: val_loss improved from 1.84897 to 1.68574, saving model to MLP.weights.best.hdf5
# Epoch 4/20
#  - 31s - loss: 1.7602 - acc: 0.3717 - val_loss: 1.6813 - val_acc: 0.3994
#
# Epoch 00004: val_loss improved from 1.68574 to 1.68133, saving model to MLP.weights.best.hdf5
# Epoch 5/20
#  - 28s - loss: 1.7122 - acc: 0.3871 - val_loss: 1.6573 - val_acc: 0.3982
#
# Epoch 00005: val_loss improved from 1.68133 to 1.65732, saving model to MLP.weights.best.hdf5
# Epoch 6/20
#  - 27s - loss: 1.6802 - acc: 0.3995 - val_loss: 1.6086 - val_acc: 0.4216
#
# Epoch 00006: val_loss improved from 1.65732 to 1.60863, saving model to MLP.weights.best.hdf5
# Epoch 7/20
#  - 27s - loss: 1.6436 - acc: 0.4112 - val_loss: 1.6068 - val_acc: 0.4294
#
# Epoch 00007: val_loss improved from 1.60863 to 1.60680, saving model to MLP.weights.best.hdf5
# Epoch 8/20
#  - 25s - loss: 1.6228 - acc: 0.4206 - val_loss: 1.5697 - val_acc: 0.4426
#
# Epoch 00008: val_loss improved from 1.60680 to 1.56967, saving model to MLP.weights.best.hdf5
# Epoch 9/20
#  - 27s - loss: 1.5995 - acc: 0.4287 - val_loss: 1.5478 - val_acc: 0.4558
#
# Epoch 00009: val_loss improved from 1.56967 to 1.54780, saving model to MLP.weights.best.hdf5
# Epoch 10/20
#  - 25s - loss: 1.5760 - acc: 0.4373 - val_loss: 1.5343 - val_acc: 0.4626
#
# Epoch 00010: val_loss improved from 1.54780 to 1.53426, saving model to MLP.weights.best.hdf5
# Epoch 11/20
#  - 25s - loss: 1.5597 - acc: 0.4440 - val_loss: 1.5155 - val_acc: 0.4566
#
# Epoch 00011: val_loss improved from 1.53426 to 1.51553, saving model to MLP.weights.best.hdf5
# Epoch 12/20
#  - 30s - loss: 1.5428 - acc: 0.4530 - val_loss: 1.5167 - val_acc: 0.4678
#
# Epoch 00012: val_loss did not improve from 1.51553
# Epoch 13/20
#  - 26s - loss: 1.5276 - acc: 0.4564 - val_loss: 1.4992 - val_acc: 0.4762
#
# Epoch 00013: val_loss improved from 1.51553 to 1.49924, saving model to MLP.weights.best.hdf5
# Epoch 14/20
#  - 26s - loss: 1.5202 - acc: 0.4575 - val_loss: 1.4699 - val_acc: 0.4814
#
# Epoch 00014: val_loss improved from 1.49924 to 1.46991, saving model to MLP.weights.best.hdf5
# Epoch 15/20
#  - 28s - loss: 1.5083 - acc: 0.4629 - val_loss: 1.5257 - val_acc: 0.4592
#
# Epoch 00015: val_loss did not improve from 1.46991
# Epoch 16/20
#  - 25s - loss: 1.4915 - acc: 0.4671 - val_loss: 1.4567 - val_acc: 0.4848
#
# Epoch 00016: val_loss improved from 1.46991 to 1.45672, saving model to MLP.weights.best.hdf5
# Epoch 17/20
#  - 27s - loss: 1.4827 - acc: 0.4718 - val_loss: 1.4760 - val_acc: 0.4796
#
# Epoch 00017: val_loss did not improve from 1.45672
# Epoch 18/20
#  - 29s - loss: 1.4672 - acc: 0.4774 - val_loss: 1.4620 - val_acc: 0.4912
#
# Epoch 00018: val_loss did not improve from 1.45672
# Epoch 19/20
#  - 28s - loss: 1.4557 - acc: 0.4782 - val_loss: 1.4580 - val_acc: 0.4822
#
# Epoch 00019: val_loss did not improve from 1.45672
# Epoch 20/20
#  - 25s - loss: 1.4526 - acc: 0.4802 - val_loss: 1.5117 - val_acc: 0.4578
#
# Epoch 00020: val_loss did not improve from 1.45672

# %% [markdown]
# # Visualisation

# %%
print(History.history.keys())
plt.plot(History.history['acc'])
plt.plot(History.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.xticks(range(0, 21))
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')

plt.xlabel('epoch')
plt.xticks(range(0, 21))
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # MLP: Model Evaluat.  with the weights that gaving best validat. accuracy

# %%
#model saved to 'MLP.weights.best.hdf5'
MLP.load_weights('MLP.weights.best.hdf5')
loss,test_accuracy = MLP.evaluate(x_test, y_test)
print('\n', 'Loss value' ,loss)
print('\n', 'Testing Accuracy' ,test_accuracy)
# Out:
# 10000/10000 [==============================] - 4s 401us/step
#
#  Loss value 1.457361441040039
#
#  Testing Accuracy 0.4899

# %%
# get predictions on the test set
y_pred = MLP.predict(x_test)

# %% [markdown]
# # MLP: Prediction Visualisation

# %%
figure = plt.figure(figsize=(20, 8))
for i, x in enumerate(np.random.choice(10000, size=40)):
    img = figure.add_subplot(5, 8, i + 1, xticks=[], yticks=[])
    img.imshow(np.squeeze(x_test[x]))
    pred_id = np.argmax(y_pred[x])
    true_id = np.argmax(y_test[x])
    img.set_title("{} ({})".format(ten[pred_id], ten[true_id]),color=("darkgreen" if pred_id == true_id else "red"))
